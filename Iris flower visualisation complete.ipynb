# %%
###Advanced data  visualization of Iris flower data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
ir=pd.read_csv(r"/Users/myyntiimac/Desktop/iris.csv")
ir
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
ir.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ir.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
ir.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
ir.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
ir.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
ir.drop('Id',axis=1,inplace=True)

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
ir['Species'] = ir['Species'].astype('category')

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Data visualization

# %%
ir['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#Lets see the count or frequency of each catagory by making bar_graph with seaborn  countplot visualization
sns.countplot(x='Species',data=ir,)
plt.show()

# %%
#In this graph we see each catagory frequency or count same which represents 50

# %%
## Check the 2 column containing continous variable is there have any asssociation betweeen them 
#for this we use jointplot, where we can see individual distribution of eavch variable with scatter plot
# lets say we want to see sepal wideth and sepal length
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=ir)
fig

# %%
#using the hue,hue="species"
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=ir,hue="Species")
fig

# %%
#Seaborn jointplot provides several customization options, such as choosing different color palettes, adding regression lines, 
#and specifying the type of plot (scatter, hexbin, or kde).

# %%
#using reg line in kind
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=ir,kind="hex")
fig

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=ir,kind="reg")
fig

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=ir,hue="Species", kind="kde")
fig

# %%
#There are also two options for bin-based visualization of the joint distribution. The first, with kind="hist"
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=ir,kind="hist")
fig

# %%
##in joint plot, in scatter portion we  see in different fomat iris setosa  easily differentiate from others
# others two have similarity in sepal wideth and leength 
#and in distribution plot , we can see sepal lenght is kind of uniform distribution  where iris setosa pure bell shape 
# for wideth , verginca and vergicolr have bell shape othrer one not

# %%
#Box plot give a statical summary of the features being plotted
#max, min, median and interquartile
fig=plt.gcf()
fig.set_size_inches(8,7)
fig=sns.boxplot(x='Species',y='PetalLengthCm',data=ir,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)

# %%
# by using the "by" parameter with the value "Species",
#the boxplot will be created for each unique species in the iris dataset. 
#The "Species" column likely contains categorical data indicating different types of iris flowers (such as setosa, versicolor, and virginica).

# %%
ir.boxplot(by="Species", figsize=(16, 4))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
# so in this above plot , we created box plot for everu species and for yaxies in 4 diferent attribute

# %%
#strip plot is a type of data visualization that displays the distribution of a continuous variable(s) across categories
#first fig a and fig size in inches, thats define the figure size 
# then  create the visualization in same operation code house, where zitter prevent overlapin the data point
#palette or color winter like some kind of blue, orient is vertical
fig = plt.gcf()
fig.set_size_inches(10, 7)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=ir,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
#combine the box plot and stripplot in same code operation house
# first define the figure size , then  create each plot one by one
fig=plt.gcf()
fig.set_size_inches(12,8)
fig=sns.boxplot(x='Species',y="SepalLengthCm", data=ir)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=ir,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
#to change the color of boxes

ax=sns.boxplot(x='Species',y="SepalLengthCm", data=ir,)
ax=sns.stripplot(x='Species',y='SepalLengthCm',data=ir,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v')
# Define the desired face colors for each box
box_colors = ['red', 'green', 'blue']
# Iterate over the artists (boxes) in the plot and assign colors
for i, artist in enumerate(ax.artists):
    artist.set_facecolor(box_colors[i])
    plt.show()

# %%
# changing the colors

ax= sns.stripplot(x="Species", y="PetalWidthCm", data=ir, jitter=True, edgecolor="gray")

colors = ['red', 'green', 'blue']

# Create the box plot
ax = sns.boxplot(x="Species", y="PetalWidthCm", data=ir, width=0.5,palette=colors)

plt.show()

# %%
#Violin Plot It is used to visualize the distribution of data and its probability distribution.
#This chart is a combination of a Box Plot and a Density Plot that is rotated and placed on each side, 
#to show the distribution shape of the data.
fig=plt.gcf()
fig.set_size_inches(12,8)
fig=sns.violinplot(x='Species',y='SepalLengthCm',data=ir)
fig
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=ir)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=ir)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=ir)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=ir)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
##pairplot
#The pairplot function in seaborn is used to plot pairwise relationships between variables in a dataset. 
#It creates a matrix of scatter plots where each variable is plotted against every other variable

# %%
#in pair plot like hitmap we use to find corelation among all continous variable in df
#in here also use hue as target variable
sns.pairplot(ir,hue='Species');

# %%
# if we want see corelation among the numerical variable
sns.pairplot(ir,kind="scatter");

# %% [markdown]
# # HeatMap
# #sns.heatmap() is used to create the heatmap.
# iris.corr() computes the correlation matrix of the Iris dataset using the corr() function. This matrix contains the pairwise correlations between the numerical columns of the dataset.
#
# annot=True displays the correlation values in each cell of the heatmap.
#
# cmap='cubehelix' sets the color map of the heatmap to 'cubehelix', which is a colormap that varies smoothly between different colors.
#
# linewidths=1 sets the width of the lines separating each cell in the heatmap to 1.
#
# linecolor='k' sets the color of the lines separating each cell to black.
#
# square=True makes each cell in the heatmap square-shaped.
#
# mask=False does not mask any cells in the heatmap.
#
# vmin=-1 and vmax=1 set the minimum and maximum values for the color scale, ensuring that the heatmap ranges from -1 to 1, representing the correlation values.
#
# cbar_kws={"orientation": "vertical"} specifies the keyword arguments for the colorbar. In this case, it sets the orientation of the colorbar to vertical.
#
# cbar=True displays a colorbar next to the heatmap.

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(ir.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
fig=plt.gcf()
fig.set_size_inches(12,8)
fig=sns.heatmap(ir.corr(),annot=True,cmap="cubehelix",linewidths=1,linecolor="k",square=True,mask=False,vmin=-1,vmax=1,cbar_kws={"orientation":"vertical"},cbar=True)

# %%
#Distribution plot,The distribution plot is suitable for comparing range and distribution for groups of numerical data.
#Data is plotted as value points along an x axis , on the y axis is show the count or frequency of the range or interval
# so in here we can see distribution plot  of all numerical atribute together
fig=plt.gcf()
fig.set_size_inches(12,6)
ir.hist(edgecolor='black', linewidth=1.2)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
##swarm plot , almost like stripplot
#A swarm plot, also known as a beeswarm plot, is a type of categorical scatter plot 
#that displays individual data points along an axis based on their categorical variables.
sns.set(style="darkgrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x="Species", y="PetalLengthCm", data=ir)

# %%
#Combining swarmplot and Violinplot with same data
#define the figure size with plt than code for both
sns.set_style("darkgrid", {"axes.facecolor": ".9", "grid.color": "0.2"})
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=ir, inner=None)
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=ir,color="red", edgecolor="black")

# %%
sns.set_style("whitegrid")
fig=plt.gcf()
fig.set_size_inches(12,8)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=ir, inner=None)
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=ir,color="green")

# %%
##Linear regression model
# to find the association between two continous variable
fig=sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=ir)

# %%
fig=sns.lmplot(x="SepalLengthCm", y="SepalWidthCm",data=ir)

# %%
fig=sns.lmplot(x="SepalLengthCm", y="PetalLengthCm",data=ir)

# %%
fig=sns.lmplot(x="SepalWidthCm", y="PetalWidthCm",data=ir,hue='Species')

# %%
#Facedgrid,sns.FacetGrid: This is a class in seaborn used to create a grid of subplots based on a variable in the dataset. 
#It allows you to easily visualize and compare distributions 
#or relationships across different subsets of the data.
# first define subplot
a=sns.FacetGrid(ir, hue="Species",height=6)
# then map with the distribution or rlatiotionship code with subplot
a.map(sns.kdeplot, "PetalLengthCm")
#if you want to add legend
a.add_legend()

# %%
#actorplot function has been deprecated since version 0.9.0. It has been replaced by the more flexible catplot function. 
#The catplot function can be used to create various types of categorical plots based on the kind parameter.
sns.catplot(x='Species', y='SepalLengthCm', hue='Species', data=ir, kind='bar')

# %%
#show the average value of each catagory
sns.catplot(x='Species', y='SepalLengthCm', hue='Species', data=ir, kind='point')

# %%
sns.catplot(x='Species', y='SepalLengthCm', hue='Species', data=ir, kind='swarm')

# %%
#boxenplot
#It is an extension of the box plot that provides additional information about the shape and variability of the data.
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='Species',y='SepalLengthCm',data=ir)

# %%
##KDE plot in this case may be because it allows you to see the shape and density of the distribution of sepal length versus sepal width
#for the 'Iris-setosa' species
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.
sub = ir[ir['Species'] == 'Iris-setosa']
sns.kdeplot(data=sub, x='SepalLengthCm', y='SepalWidthCm', shade=True, cmap='Reds')

plt.title('Iris-setosa')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
sns.set_style('whitegrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(x="Species", y="PetalLengthCm", data=ir,ax=axes[0,0])
k2=sns.violinplot(x='Species',y='PetalLengthCm',data=ir,ax=axes[0,1])
k3=sns.stripplot(x='Species',y='SepalLengthCm',data=ir,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
k4=axes[1,1].hist(ir.PetalLengthCm,bins=100)
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(13,13))

sns.boxplot(x="Species", y="PetalLengthCm", data=ir,ax=axes[0,0])
sns.violinplot(x='Species',y='PetalLengthCm',data=ir,ax=axes[0,1])
sns.stripplot(x='Species',y='SepalLengthCm',data=ir,jitter=True,edgecolor='black',size=6,palette='winter',orient='v',ax=axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
axes[1,1].hist(ir.PetalLengthCm,bins=100)
#k2.set(xlim=(-1,0.8))
plt.show()

# %%
#Area Plot: Area Plot gives us a visual representation of Various dimensions of Iris flower 
#and their range in dataset.
ir.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6));
